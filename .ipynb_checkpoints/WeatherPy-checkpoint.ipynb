# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import openweathermapy as owm
import random

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

import csv
# Output File (CSV)
output_data_file = "output_data/cities.csv"


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#settings = {"units": "imperial", "appid":api_key}
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={api_key}&units={units}&q="

# %%
city2 = []
cloudiness = []
dates = []
humidity = []
lats = []
lngs = []
max_temp = []
wind_speed = []
country = []

count = 1
error = 0
index = 0
sets = 0
print(f"Beginning Data Retrieval \n .......................")
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        dates.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        index = index +1
        
        if count > 48:
            count = 1
            sets += 1
            city2.append(city)
        else:
            count += 1
            city2.append(city)
        print(f"Processing Record {count} of Set {sets} | {city}")
    except Exception as e:
        print(e)
        error= error+1
        print("Unable to locate this city.. Moving along...")
print("------------------------------\n Data Retrieval Complete \n------------------------------")
# Out:
# Beginning Data Retrieval
#  .......................
# Processing Record 2 of Set 0 | rikitea
# Processing Record 3 of Set 0 | airai
# Processing Record 4 of Set 0 | lakes entrance
# Processing Record 5 of Set 0 | cape town
# Processing Record 6 of Set 0 | guerrero negro
# Processing Record 7 of Set 0 | upernavik
# Processing Record 8 of Set 0 | mataura
# Processing Record 9 of Set 0 | monduli
# Processing Record 10 of Set 0 | sal rei
# Processing Record 11 of Set 0 | grand gaube
# Processing Record 12 of Set 0 | hobart
# Processing Record 13 of Set 0 | tocopilla
# Processing Record 14 of Set 0 | busselton
# Processing Record 15 of Set 0 | pevek
# Processing Record 16 of Set 0 | hithadhoo
# Processing Record 17 of Set 0 | lebu
# Processing Record 18 of Set 0 | vaini
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 19 of Set 0 | ushuaia
# Processing Record 20 of Set 0 | tuktoyaktuk
# Processing Record 21 of Set 0 | new norfolk
# Processing Record 22 of Set 0 | vardo
# Processing Record 23 of Set 0 | katsuura
# Processing Record 24 of Set 0 | geraldton
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 25 of Set 0 | griffith
# Processing Record 26 of Set 0 | cabo san lucas
# Processing Record 27 of Set 0 | atuona
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 28 of Set 0 | arraial do cabo
# Processing Record 29 of Set 0 | port elizabeth
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 30 of Set 0 | lobito
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 31 of Set 0 | nchelenge
# Processing Record 32 of Set 0 | plettenberg bay
# Processing Record 33 of Set 0 | punta arenas
# Processing Record 34 of Set 0 | yuanping
# Processing Record 35 of Set 0 | bluff
# Processing Record 36 of Set 0 | kingsburg
# Processing Record 37 of Set 0 | yellowknife
# Processing Record 38 of Set 0 | carnarvon
# Processing Record 39 of Set 0 | flinders
# Processing Record 40 of Set 0 | puerto colombia
# Processing Record 41 of Set 0 | ilulissat
# Processing Record 42 of Set 0 | tasiilaq
# Processing Record 43 of Set 0 | longyearbyen
# Processing Record 44 of Set 0 | kaitangata
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 45 of Set 0 | butaritari
# Processing Record 46 of Set 0 | ponta do sol
# Processing Record 47 of Set 0 | hermanus
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 48 of Set 0 | fortuna
# Processing Record 49 of Set 0 | castro
# Processing Record 1 of Set 1 | puerto escondido
# Processing Record 2 of Set 1 | royan
# Processing Record 3 of Set 1 | torbay
# Processing Record 4 of Set 1 | fuerte olimpo
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | langgons
# Processing Record 7 of Set 1 | marsh harbour
# Processing Record 8 of Set 1 | melilla
# Processing Record 9 of Set 1 | alugan
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | cherskiy
# Processing Record 12 of Set 1 | morondava
# Processing Record 13 of Set 1 | cianorte
# Processing Record 14 of Set 1 | zambezi
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | lavrentiya
# Processing Record 17 of Set 1 | neuquen
# Processing Record 18 of Set 1 | pinega
# Processing Record 19 of Set 1 | taoudenni
# Processing Record 20 of Set 1 | norman wells
# Processing Record 21 of Set 1 | sao joao da barra
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | rawson
# Processing Record 24 of Set 1 | kurumkan
# Processing Record 25 of Set 1 | sarkand
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | ambilobe
# Processing Record 28 of Set 1 | yashkul
# Processing Record 29 of Set 1 | xuddur
# Processing Record 30 of Set 1 | maun
# Processing Record 31 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | kavieng
# Processing Record 34 of Set 1 | calella
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 35 of Set 1 | alofi
# Processing Record 36 of Set 1 | cidreira
# Processing Record 37 of Set 1 | srednekolymsk
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | merrill
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 40 of Set 1 | mahebourg
# Processing Record 41 of Set 1 | emerald
# Processing Record 42 of Set 1 | teeli
# Processing Record 43 of Set 1 | cocobeach
# Processing Record 44 of Set 1 | codrington
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 45 of Set 1 | laguna
# Processing Record 46 of Set 1 | saurimo
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 47 of Set 1 | tiksi
# Processing Record 48 of Set 1 | bilibino
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 1 of Set 2 | bonavista
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 2 of Set 2 | kitami
# Processing Record 3 of Set 2 | hambantota
# Processing Record 4 of Set 2 | nova olimpia
# Processing Record 5 of Set 2 | saint-philippe
# 'clouds'
# Unable to locate this city.. Moving along...
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 6 of Set 2 | jaciara
# Processing Record 7 of Set 2 | opuwo
# Processing Record 8 of Set 2 | bosaso
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | port-gentil
# Processing Record 11 of Set 2 | cervo
# Processing Record 12 of Set 2 | sao joao da ponte
# Processing Record 13 of Set 2 | labuhan
# Processing Record 14 of Set 2 | port lincoln
# Processing Record 15 of Set 2 | launceston
# Processing Record 16 of Set 2 | atar
# Processing Record 17 of Set 2 | fort myers beach
# Processing Record 18 of Set 2 | coquimbo
# Processing Record 19 of Set 2 | sorsk
# Processing Record 20 of Set 2 | bayir
# Processing Record 21 of Set 2 | jiuquan
# Processing Record 22 of Set 2 | marawi
# Processing Record 23 of Set 2 | hilo
# Processing Record 24 of Set 2 | egvekinot
# Processing Record 25 of Set 2 | aswan
# Processing Record 26 of Set 2 | jawhar
# Processing Record 27 of Set 2 | kjollefjord
# Processing Record 28 of Set 2 | georgetown
# Processing Record 29 of Set 2 | gizo
# Processing Record 30 of Set 2 | kruisfontein
# Processing Record 31 of Set 2 | hasaki
# Processing Record 32 of Set 2 | novobirilyussy
# Processing Record 33 of Set 2 | qaanaaq
# Processing Record 34 of Set 2 | huilong
# Processing Record 35 of Set 2 | homer
# Processing Record 36 of Set 2 | sheridan
# Processing Record 37 of Set 2 | aitape
# Processing Record 38 of Set 2 | sonegaon
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | barbalha
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 41 of Set 2 | najran
# Processing Record 42 of Set 2 | kutum
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 43 of Set 2 | namibe
# Processing Record 44 of Set 2 | comodoro rivadavia
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 45 of Set 2 | balaguer
# Processing Record 46 of Set 2 | khatanga
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 47 of Set 2 | chuy
# Processing Record 48 of Set 2 | pueblo bello
# Processing Record 49 of Set 2 | praia da vitoria
# Processing Record 1 of Set 3 | yatsushiro
# Processing Record 2 of Set 3 | kabompo
# Processing Record 3 of Set 3 | lufilufi
# Processing Record 4 of Set 3 | artyom
# Processing Record 5 of Set 3 | pasighat
# Processing Record 6 of Set 3 | sinnamary
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 7 of Set 3 | corumba
# Processing Record 8 of Set 3 | ilhabela
# Processing Record 9 of Set 3 | souillac
# Processing Record 10 of Set 3 | east london
# Processing Record 11 of Set 3 | impfondo
# 'clouds'
# Unable to locate this city.. Moving along...
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 12 of Set 3 | dubovskoye
# Processing Record 13 of Set 3 | misratah
# Processing Record 14 of Set 3 | saskylakh
# Processing Record 15 of Set 3 | nuuk
# Processing Record 16 of Set 3 | rio gallegos
# Processing Record 17 of Set 3 | moerai
# Processing Record 18 of Set 3 | tual
# Processing Record 19 of Set 3 | lisala
# Processing Record 20 of Set 3 | thompson
# Processing Record 21 of Set 3 | mount gambier
# Processing Record 22 of Set 3 | takapau
# Processing Record 23 of Set 3 | ippy
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 24 of Set 3 | jambi
# Processing Record 25 of Set 3 | pembroke
# Processing Record 26 of Set 3 | klaksvik
# Processing Record 27 of Set 3 | port alfred
# Processing Record 28 of Set 3 | grindavik
# Processing Record 29 of Set 3 | port hardy
# Processing Record 30 of Set 3 | praia
# Processing Record 31 of Set 3 | sioux lookout
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 32 of Set 3 | mataya
# Processing Record 33 of Set 3 | port blair
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 34 of Set 3 | mys shmidta
# Processing Record 35 of Set 3 | kysyl-syr
# Processing Record 36 of Set 3 | dubovka
# Processing Record 37 of Set 3 | luau
# Processing Record 38 of Set 3 | kodinsk
# Processing Record 39 of Set 3 | lagos
# Processing Record 40 of Set 3 | atasu
# Processing Record 41 of Set 3 | provideniya
# Processing Record 42 of Set 3 | arvika
# Processing Record 43 of Set 3 | touros
# Processing Record 44 of Set 3 | honiara
# Processing Record 45 of Set 3 | mar del plata
# Processing Record 46 of Set 3 | katherine
# Processing Record 47 of Set 3 | bur gabo
# Processing Record 48 of Set 3 | shestakovo
# Processing Record 49 of Set 3 | clyde river
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 1 of Set 4 | ocu
# Processing Record 2 of Set 4 | padang
# Processing Record 3 of Set 4 | smithers
# Processing Record 4 of Set 4 | okha
# Processing Record 5 of Set 4 | stawell
# Processing Record 6 of Set 4 | muli
# Processing Record 7 of Set 4 | victoria
# Processing Record 8 of Set 4 | kahului
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 9 of Set 4 | obidos
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 10 of Set 4 | bhan
# Processing Record 11 of Set 4 | presidente medici
# Processing Record 12 of Set 4 | aksu
# Processing Record 13 of Set 4 | bathsheba
# Processing Record 14 of Set 4 | ivolginsk
# Processing Record 15 of Set 4 | sol-iletsk
# Processing Record 16 of Set 4 | nouadhibou
# Processing Record 17 of Set 4 | pizarro
# Processing Record 18 of Set 4 | kuryk
# Processing Record 19 of Set 4 | erzin
# Processing Record 20 of Set 4 | prado
# Processing Record 21 of Set 4 | lajas
# Processing Record 22 of Set 4 | raudeberg
# Processing Record 23 of Set 4 | fort nelson
# Processing Record 24 of Set 4 | killybegs
# Processing Record 25 of Set 4 | miles city
# 'clouds'
# Unable to locate this city.. Moving along...
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 26 of Set 4 | murray bridge
# Processing Record 27 of Set 4 | narsaq
# Processing Record 28 of Set 4 | iqaluit
# Processing Record 29 of Set 4 | soyo
# Processing Record 30 of Set 4 | esso
# Processing Record 31 of Set 4 | wawa
# Processing Record 32 of Set 4 | lorengau
# Processing Record 33 of Set 4 | margate
# Processing Record 34 of Set 4 | yakeshi
# Processing Record 35 of Set 4 | pangnirtung
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 36 of Set 4 | mmabatho
# Processing Record 37 of Set 4 | salalah
# Processing Record 38 of Set 4 | hobyo
# Processing Record 39 of Set 4 | sorata
# Processing Record 40 of Set 4 | unity
# Processing Record 41 of Set 4 | athabasca
# Processing Record 42 of Set 4 | grand river south east
# Processing Record 43 of Set 4 | vila velha
# Processing Record 44 of Set 4 | soure
# Processing Record 45 of Set 4 | olhao
# Processing Record 46 of Set 4 | tuatapere
# Processing Record 47 of Set 4 | zhanakorgan
# Processing Record 48 of Set 4 | gigmoto
# Processing Record 49 of Set 4 | fare
# Processing Record 1 of Set 5 | hualmay
# Processing Record 2 of Set 5 | areado
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 3 of Set 5 | koksovyy
# Processing Record 4 of Set 5 | karratha
# Processing Record 5 of Set 5 | pervomayskiy
# Processing Record 6 of Set 5 | naryan-mar
# Processing Record 7 of Set 5 | luena
# Processing Record 8 of Set 5 | kandrian
# Processing Record 9 of Set 5 | mastic beach
# Processing Record 10 of Set 5 | nizhniy kuranakh
# Processing Record 11 of Set 5 | moroni
# Processing Record 12 of Set 5 | nikolskoye
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 13 of Set 5 | istmina
# Processing Record 14 of Set 5 | saint-augustin
# Processing Record 15 of Set 5 | renukut
# Processing Record 16 of Set 5 | mishan
# Processing Record 17 of Set 5 | lerwick
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 18 of Set 5 | eutin
# Processing Record 19 of Set 5 | mayo
# Processing Record 20 of Set 5 | milledgeville
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 21 of Set 5 | adrar
# Processing Record 22 of Set 5 | port shepstone
# Processing Record 23 of Set 5 | mao
# Processing Record 24 of Set 5 | denpasar
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 25 of Set 5 | businga
# Processing Record 26 of Set 5 | kavaratti
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 27 of Set 5 | chokurdakh
# Processing Record 28 of Set 5 | yulara
# Processing Record 29 of Set 5 | leningradskiy
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 30 of Set 5 | lompoc
# Processing Record 31 of Set 5 | pisco
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 32 of Set 5 | tessalit
# Processing Record 33 of Set 5 | westport
# Processing Record 34 of Set 5 | severo-kurilsk
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 35 of Set 5 | zhigalovo
# Processing Record 36 of Set 5 | tara
# Processing Record 37 of Set 5 | bosilegrad
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 38 of Set 5 | bethel
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 39 of Set 5 | bambous virieux
# Processing Record 40 of Set 5 | navolato
# Processing Record 41 of Set 5 | buala
# Processing Record 42 of Set 5 | paita
# Processing Record 43 of Set 5 | tiszaalpar
# Processing Record 44 of Set 5 | mount pleasant
# Processing Record 45 of Set 5 | arman
# Processing Record 46 of Set 5 | ancud
# Processing Record 47 of Set 5 | gewane
# Processing Record 48 of Set 5 | sabha
# Processing Record 49 of Set 5 | hameenlinna
# Processing Record 1 of Set 6 | cristalina
# Processing Record 2 of Set 6 | jacareacanga
# Processing Record 3 of Set 6 | merke
# Processing Record 4 of Set 6 | poperinge
# Processing Record 5 of Set 6 | antigonish
# 'clouds'
# Unable to locate this city.. Moving along...
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 6 of Set 6 | high level
# Processing Record 7 of Set 6 | kupang
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 8 of Set 6 | bilma
# Processing Record 9 of Set 6 | meulaboh
# Processing Record 10 of Set 6 | polunochnoye
# Processing Record 11 of Set 6 | kinablangan
# Processing Record 12 of Set 6 | dedougou
# Processing Record 13 of Set 6 | tautira
# Processing Record 14 of Set 6 | doha
# Processing Record 15 of Set 6 | borogontsy
# Processing Record 16 of Set 6 | japura
# Processing Record 17 of Set 6 | barra dos coqueiros
# Processing Record 18 of Set 6 | orel-izumrud
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 19 of Set 6 | pathein
# Processing Record 20 of Set 6 | manokwari
# 'clouds'
# Unable to locate this city.. Moving along...
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 21 of Set 6 | mangaldai
# Processing Record 22 of Set 6 | poum
# Processing Record 23 of Set 6 | ishigaki
# Processing Record 24 of Set 6 | tangzhai
# Processing Record 25 of Set 6 | ahipara
# Processing Record 26 of Set 6 | jalu
# Processing Record 27 of Set 6 | mnogovershinnyy
# Processing Record 28 of Set 6 | hokitika
# Processing Record 29 of Set 6 | nanortalik
# Processing Record 30 of Set 6 | helena
# Processing Record 31 of Set 6 | dingle
# Processing Record 32 of Set 6 | omsukchan
# Processing Record 33 of Set 6 | port hedland
# Processing Record 34 of Set 6 | saint-pierre
# Processing Record 35 of Set 6 | elizabeth city
# Processing Record 36 of Set 6 | akureyri
# Processing Record 37 of Set 6 | muisne
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 38 of Set 6 | banjar
# Processing Record 39 of Set 6 | willowmore
# Processing Record 40 of Set 6 | chulman
# 'clouds'
# Unable to locate this city.. Moving along...
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 41 of Set 6 | fuyu
# Processing Record 42 of Set 6 | biak
# 'clouds'
# Unable to locate this city.. Moving along...
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 43 of Set 6 | faya
# Processing Record 44 of Set 6 | kirovskiy
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 45 of Set 6 | jinchang
# Processing Record 46 of Set 6 | botwood
# Processing Record 47 of Set 6 | ulladulla
# Processing Record 48 of Set 6 | miramar
# Processing Record 49 of Set 6 | san patricio
# Processing Record 1 of Set 7 | coahuayana
# Processing Record 2 of Set 7 | faanui
# Processing Record 3 of Set 7 | mapastepec
# Processing Record 4 of Set 7 | gallup
# Processing Record 5 of Set 7 | kizukuri
# Processing Record 6 of Set 7 | san rafael
# Processing Record 7 of Set 7 | kaputa
# Processing Record 8 of Set 7 | sim
# Processing Record 9 of Set 7 | ternate
# Processing Record 10 of Set 7 | mapiripan
# Processing Record 11 of Set 7 | bac lieu
# Processing Record 12 of Set 7 | wagar
# Processing Record 13 of Set 7 | sumbe
# Processing Record 14 of Set 7 | lock haven
# Processing Record 15 of Set 7 | kalabo
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 16 of Set 7 | cabedelo
# Processing Record 17 of Set 7 | melo
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 18 of Set 7 | marystown
# Processing Record 19 of Set 7 | ostrovnoy
# Processing Record 20 of Set 7 | san buenaventura
# Processing Record 21 of Set 7 | havre-saint-pierre
# Processing Record 22 of Set 7 | puerto madryn
# Processing Record 23 of Set 7 | nicoya
# Processing Record 24 of Set 7 | yamandu
# Processing Record 25 of Set 7 | vao
# Processing Record 26 of Set 7 | iranshahr
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 27 of Set 7 | sao gabriel da cachoeira
# Processing Record 28 of Set 7 | lazaro cardenas
# Processing Record 29 of Set 7 | nador
# Processing Record 30 of Set 7 | virginia beach
# Processing Record 31 of Set 7 | san cristobal
# Processing Record 32 of Set 7 | shimanovsk
# Processing Record 33 of Set 7 | molde
# Processing Record 34 of Set 7 | ouegoa
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 35 of Set 7 | palmerston
# Processing Record 36 of Set 7 | peci
# Processing Record 37 of Set 7 | batagay-alyta
# Processing Record 38 of Set 7 | rocha
# Processing Record 39 of Set 7 | semnan
# 'clouds'
# Unable to locate this city.. Moving along...
# 'clouds'
# Unable to locate this city.. Moving along...
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 40 of Set 7 | kasongo-lunda
# Processing Record 41 of Set 7 | bhadrak
# Processing Record 42 of Set 7 | pochutla
# 'clouds'
# Unable to locate this city.. Moving along...
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 43 of Set 7 | aripuana
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 44 of Set 7 | qaqortoq
# Processing Record 45 of Set 7 | dali
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 46 of Set 7 | beloha
# Processing Record 47 of Set 7 | portland
# Processing Record 48 of Set 7 | nokaneng
# Processing Record 49 of Set 7 | kondinskoye
# Processing Record 1 of Set 8 | mahanoro
# Processing Record 2 of Set 8 | kiunga
# Processing Record 3 of Set 8 | tiznit
# 'clouds'
# Unable to locate this city.. Moving along...
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 4 of Set 8 | troitskoye
# Processing Record 5 of Set 8 | ipswich
# Processing Record 6 of Set 8 | red wing
# Processing Record 7 of Set 8 | san ignacio
# Processing Record 8 of Set 8 | turukhansk
# Processing Record 9 of Set 8 | foso
# Processing Record 10 of Set 8 | barras
# Processing Record 11 of Set 8 | natal
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 12 of Set 8 | tashtyp
# Processing Record 13 of Set 8 | corum
# Processing Record 14 of Set 8 | sarankhola
# Processing Record 15 of Set 8 | mangrol
# Processing Record 16 of Set 8 | noumea
# Processing Record 17 of Set 8 | sao filipe
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 18 of Set 8 | oruro
# Processing Record 19 of Set 8 | nokha
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 20 of Set 8 | gornopravdinsk
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 21 of Set 8 | spassk-ryazanskiy
# Processing Record 22 of Set 8 | terrace
# Processing Record 23 of Set 8 | kohima
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 24 of Set 8 | kendari
# Processing Record 25 of Set 8 | mercedes
# Processing Record 26 of Set 8 | nguruka
# Processing Record 27 of Set 8 | yarada
# Processing Record 28 of Set 8 | coihaique
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 29 of Set 8 | sabang
# Processing Record 30 of Set 8 | carutapera
# Processing Record 31 of Set 8 | nantucket
# Processing Record 32 of Set 8 | luderitz
# Processing Record 33 of Set 8 | hamilton
# Processing Record 34 of Set 8 | nuevo progreso
# Processing Record 35 of Set 8 | acapulco
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 36 of Set 8 | gravdal
# Processing Record 37 of Set 8 | anadyr
# Processing Record 38 of Set 8 | burns lake
# Processing Record 39 of Set 8 | kenai
# Processing Record 40 of Set 8 | talnakh
# Processing Record 41 of Set 8 | mokhsogollokh
# 'clouds'
# Unable to locate this city.. Moving along...
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 42 of Set 8 | necochea
# Processing Record 43 of Set 8 | batticaloa
# Processing Record 44 of Set 8 | ola
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 45 of Set 8 | mahibadhoo
# Processing Record 46 of Set 8 | parrita
# Processing Record 47 of Set 8 | kununurra
# Processing Record 48 of Set 8 | moose factory
# Processing Record 49 of Set 8 | diffa
# 'clouds'
# Unable to locate this city.. Moving along...
# 'clouds'
# Unable to locate this city.. Moving along...
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 1 of Set 9 | annonay
# Processing Record 2 of Set 9 | edeleny
# 'clouds'
# Unable to locate this city.. Moving along...
# 'clouds'
# Unable to locate this city.. Moving along...
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 3 of Set 9 | lahaina
# Processing Record 4 of Set 9 | eldorado
# Processing Record 5 of Set 9 | esperance
# Processing Record 6 of Set 9 | marzuq
# Processing Record 7 of Set 9 | sisimiut
# Processing Record 8 of Set 9 | wattegama
# Processing Record 9 of Set 9 | kaeo
# Processing Record 10 of Set 9 | tongchuan
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 11 of Set 9 | yerbogachen
# Processing Record 12 of Set 9 | ilorin
# Processing Record 13 of Set 9 | kota kinabalu
# Processing Record 14 of Set 9 | fairbanks
# Processing Record 15 of Set 9 | vila franca do campo
# Processing Record 16 of Set 9 | karoi
# Processing Record 17 of Set 9 | cockburn harbour
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 18 of Set 9 | sinjar
# Processing Record 19 of Set 9 | pindushi
# Processing Record 20 of Set 9 | gualeguay
# Processing Record 21 of Set 9 | cap malheureux
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 22 of Set 9 | ilo
# Processing Record 23 of Set 9 | lumberton
# Processing Record 24 of Set 9 | nacala
# Processing Record 25 of Set 9 | mineiros
# Processing Record 26 of Set 9 | winneba
# Processing Record 27 of Set 9 | muroto
# Processing Record 28 of Set 9 | cabra
# Processing Record 29 of Set 9 | berlevag
# Processing Record 30 of Set 9 | ajdabiya
# Processing Record 31 of Set 9 | saryozek
# Processing Record 32 of Set 9 | suoyarvi
# Processing Record 33 of Set 9 | codajas
# Processing Record 34 of Set 9 | menongue
# Processing Record 35 of Set 9 | luanda
# Processing Record 36 of Set 9 | kulhudhuffushi
# Processing Record 37 of Set 9 | santiago del estero
# Processing Record 38 of Set 9 | freetown
# Processing Record 39 of Set 9 | half moon bay
# Processing Record 40 of Set 9 | san pedro
# Processing Record 41 of Set 9 | okhotsk
# Processing Record 42 of Set 9 | deputatskiy
# Processing Record 43 of Set 9 | oranjemund
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 44 of Set 9 | dawei
# Processing Record 45 of Set 9 | evensk
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 46 of Set 9 | anito
# Processing Record 47 of Set 9 | davidson
# Processing Record 48 of Set 9 | urdoma
# Processing Record 49 of Set 9 | saldanha
# Processing Record 1 of Set 10 | yar-sale
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 2 of Set 10 | chongwe
# Processing Record 3 of Set 10 | constantine
# Processing Record 4 of Set 10 | port washington
# Processing Record 5 of Set 10 | auka
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 6 of Set 10 | chachapoyas
# Processing Record 7 of Set 10 | constitucion
# Processing Record 8 of Set 10 | leninskoye
# Processing Record 9 of Set 10 | nouakchott
# Processing Record 10 of Set 10 | zhangye
# Processing Record 11 of Set 10 | senneterre
# Processing Record 12 of Set 10 | hearst
# Processing Record 13 of Set 10 | weligama
# Processing Record 14 of Set 10 | makakilo city
# Processing Record 15 of Set 10 | tairua
# Processing Record 16 of Set 10 | bria
# Processing Record 17 of Set 10 | cerro de pasco
# Processing Record 18 of Set 10 | paraiso
# Processing Record 19 of Set 10 | celendin
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 20 of Set 10 | nhulunbuy
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 21 of Set 10 | zacatepec
# Processing Record 22 of Set 10 | mamallapuram
# Processing Record 23 of Set 10 | chabahar
# Processing Record 24 of Set 10 | bako
# Processing Record 25 of Set 10 | northam
# Processing Record 26 of Set 10 | saint-joseph
# Processing Record 27 of Set 10 | itoman
# 'clouds'
# Unable to locate this city.. Moving along...
# Processing Record 28 of Set 10 | vanimo
# Processing Record 29 of Set 10 | sitka
# ------------------------------
#  Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": city2,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": dates,
    "Humidity": humidity,
    "Lat": lats,
    "Lng": lngs,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed,
}

weather_df = pd.DataFrame(weather_dict)
weather_df.count()
# Out:
# City          518
# Cloudiness    518
# Country       518
# Date          518
# Humidity      518
# Lat           518
# Lng           518
# Max Temp      518
# Wind Speed    518
# dtype: int64

# %%
weather_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         rikitea         100      PF  1571686935        80 -23.12 -134.97
# 1           airai          14      TL  1571687477        26  -8.93  125.41
# 2  lakes entrance          40      US  1571687478        53  37.50  -83.94
# 3       cape town         100      CL  1571687478        34 -36.41  -71.90
# 4  guerrero negro           0      AR  1571687479        17 -24.19  -65.45
#
#    Max Temp  Wind Speed
# 0      70.9       21.99
# 1      65.8        4.81
# 2      77.0       17.22
# 3      68.0       16.11
# 4      84.2        6.93

# %%
weather_df.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Max Temp"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Max Temperature (10/21/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("C:\\Users\\richn\\Desktop\\latvstemp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Humidity"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Humidity (10/21/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("C:\\Users\\richn\\Desktop\\latvshum.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Cloudiness"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Cloudiness (10/21/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("C:\\Users\\richn\\Desktop\\latvscloud.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Wind Speed"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Wind Speed (10/21/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("C:\\Users\\richn\\Desktop\\latvsws.png")
plt.show()
